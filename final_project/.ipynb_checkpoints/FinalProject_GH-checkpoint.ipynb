# %% [markdown]
# # COGS 108 - Final Project

# %% [markdown]
# # Overview

# %% [markdown]
# *Fill in your overview here*

# %% [markdown]
# # Name & GitHub ID
#
# - Name: Bryan Lee
# - GitHub Username: baquerst

# %% [markdown]
# # Research Question

# %% [markdown]
# *Is there a correlation between the number of recreational programs based on average neighborhood income in San Diego, California? If there is a correlation, does this have an effect on the physical health of the inhabitants?*

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Parks and recreation services are meant to serve communities by providing them with an outlet for physical activites, group activites, and places for congregation. However, it has been shown that there can be disparities in park distribution and access among neighborhoods based on income or race/ethnicity<sup>1</sup>. The study done by the National Recreation and Park Association (NPRA) investigates this disparity throughout multiple cities in America, but has not conducted a study in San Diego.
#
# Physical health is an important factor into overall the wellbeing of a person, however, a lack of resources to maintain physical health will hinder this. Local parks and recreation facilities can offer individuals many resources to stay active and maintain their physical health. Just by taking a walk in the park, a person can "help to maintain their weight, strengthen their muscles and bones, and improve balance and coordination<sup>2</sup>".
#
# Jim Sallis, the director of Active Living Research at SDSU has stated how “many low-income communities lack access to parks, recreation areas and sources of healthy foods[...] and those factors play a significant role in preventing participation in outdoor activity in their communities<sup>3</sup>” This decrease in outdoor activity could then lead to a decrease in physical health, as it has been shown how outdoor activites like walks are proven to be beneficial<sup>2</sup>.
#
# My study aims to research the number of parks and recreational programs that are available to differing neighborhoods in San Diego, and to find a discrepancy between low-income neighborhoods and non-low-income neighborhoods. I will also look into the physical wellbeing of those in low-income neighborhoods compared to non-low-income neighborhoods.
#
# References:
# 1. [Parks and Recreation in Underserved Areas: A Public Health Perspective](https://www.nrpa.org/uploadedFiles/nrpa.org/Publications_and_Research/Research/Papers/Parks-Rec-Underserved-Areas.pdf)
# 2. [The Role of Parks and Rec in Public Health](https://www.civicplus.com/blog/pr/the-role-of-parks-and-rec-in-public-health)
# 3. [Poor Neighborhoods Can Harm Health](http://newscenter.sdsu.edu/sdsu_newscenter/news_story.aspx?sid=73238)

# %% [markdown]
# # Hypothesis

# %% [markdown]
# *I hypothesize that lower income neighborhoods will have less parks and recreational programs compared to other neighborhoods. Lower income would mean less funding for parks and recreation, causing this disparity. I hypothesize the lower number of parks and recreational programs will negatively impact the physical health of those communities.*

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# - Dataset Name: San Diego Boundary Polygon
# - Link to the dataset: http://polygons.openstreetmap.fr/get_geojson.py?id=253832&params=0
# - Number of observations: 1
# - Description: I used this dataset of only 1 observation just to get a visual boundary of San Diego which I belive to be useful.
#
# - Dataset Name: Rec Center Locations Data
# - Link to the dataset: https://github.com/COGS108/individual_fa20/blob/master/data/rec_centers_datasd.geojson
# - Number of observations:
# - Description:
#
# - Dataset Name: California Environmental Health Screening Data
# - Link to the dataset: https://github.com/COGS108/individual_fa20/blob/master/data/calenviroscreen-final-report.csv
# - Number of observations:
# - Description:
#
# If you plan to use multiple datasets, add 1-2 sentences about how you plan to combine these datasets.

# %% [markdown]
# # Setup

# %%
## YOUR CODE HERE
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Describe your data cleaning steps here.

# %%
shape = gpd.read_file('./individual_fa20/final_project/zoningdatasd.geojson')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ./individual_fa20/final_project/zoningdatasd.geojson: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-33-1b559f41d5c1> in <module>
# ----> 1 shape = gpd.read_file('./individual_fa20/final_project/zoningdatasd.geojson')
#
# /usr/local/anaconda3/lib/python3.8/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#      94
#      95     with fiona_env():
# ---> 96         with reader(path_or_bytes, **kwargs) as features:
#      97
#      98             # In a future Fiona release the crs attribute of features will
#
# /usr/local/anaconda3/lib/python3.8/site-packages/fiona/env.py in wrapper(*args, **kwargs)
#     398     def wrapper(*args, **kwargs):
#     399         if local._env:
# --> 400             return f(*args, **kwargs)
#     401         else:
#     402             if isinstance(args[0], str):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/fiona/__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     254
#     255         if mode in ('a', 'r'):
# --> 256             c = Collection(path, mode, driver=driver, encoding=encoding,
#     257                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     258         elif mode == 'w':
#
# /usr/local/anaconda3/lib/python3.8/site-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     160             if self.mode == 'r':
#     161                 self.session = Session()
# --> 162                 self.session.start(self, **kwargs)
#     163             elif self.mode in ('a', 'w'):
#     164                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: ./individual_fa20/final_project/zoningdatasd.geojson: No such file or directory

# %%
sd = gpd.read_file("http://polygons.openstreetmap.fr/get_geojson.py?id=253832&params=0")
rec = gpd.read_file("https://raw.githubusercontent.com/COGS108/individual_fa20/master/data/rec_centers_datasd.geojson")

fig, ax = plt.subplots()
ax.set_aspect('equal')

sd.plot(ax=ax, color='white', edgecolor='black')
rec.plot(ax=ax, marker='o', color='red')
plt.gcf().set_size_inches(20, 10)

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

df_CES = pd.read_csv("https://raw.githubusercontent.com/COGS108/individual_fa20/master/data/calenviroscreen-final-report.csv")
df_CES = df_CES[df_CES['California County'] == 'San Diego']
 
df = df_CES[['California County', 'CES 2.0 Score', 'CES 2.0 Percentile Range', 'Pollution Burden', 'Pollution Burden Score', 'Poverty Pctl', 'Location 1']].copy()
df
# Out:
#      California County  CES 2.0 Score  CES 2.0 Percentile Range  \
# 165          San Diego          59.91  96-100% (highest scores)
# 299          San Diego          55.61  96-100% (highest scores)
# 370          San Diego          54.23  96-100% (highest scores)
# 466          San Diego          52.48                    91-95%
# 805          San Diego          47.82                    86-90%
# ...                ...            ...                       ...
# 7961         San Diego           2.93      1-5% (lowest scores)
# 8020         San Diego            NaN                       NaN
# 8021         San Diego            NaN                       NaN
# 8022         San Diego            NaN                       NaN
# 8023         San Diego            NaN                       NaN
#
#       Pollution Burden  Pollution Burden Score  Poverty Pctl  \
# 165          59.419884                7.203297         96.65
# 299          54.822326                6.645896         97.50
# 370          55.583873                6.738271         94.09
# 466          51.062659                6.190205         97.38
# 805          46.297498                5.612438         98.29
# ...                ...                     ...           ...
# 7961         18.223005                2.209116         19.24
# 8020         53.418226                6.475694           NaN
# 8021         43.163348                5.232513           NaN
# 8022         36.458148                4.419687           NaN
# 8023         31.103738                3.770639           NaN
#
#                                              Location 1
# 165   San Diego 92113\n(32.694850199999998, -117.141...
# 299   San Diego 92113\n(32.690986199999998, -117.116...
# 370   San Diego 92113\n(32.701852600000002, -117.138...
# 466   San Diego 92113\n(32.696748999999997, -117.126...
# 805   San Diego 92113\n(32.703556800000001, -117.126...
# ...                                                 ...
# 7961  San Diego 92109\n(32.804769200000003, -117.254...
# 8020  San Diego 92134\n(32.724121500000003, -117.146...
# 8021  San Diego 92101\n(32.731728599999997, -117.190...
# 8022  San Diego 92140\n(32.737718600000001, -117.197...
# 8023  Coronado 92118\n(32.712243899999997, -117.1887...
#
# [627 rows x 7 columns]

# %% [markdown]
# idea: chloropleth map of CalEnviroScreen w/ parks n rec overlayed on it use shapefile

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# Include cells that describe the steps in your data analysis.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# The data for each neighborhood/district in San Diego regarding income and number of parks and recreation should not contain personal information of an individual. The data for number of individuals with obesity will be anonymized if it contains any indentifiable information.
#
# There could be a misrepresentation of number of individuals with obesity since not every person has access to healthcare and may not be able to get diagnosed. I do not forsee any potential biases within these datasets, since they are on neighborhoods and locations, rather than people. The data should also come from the city of San Diego, a public sector.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# *Fill in your discussion information here*
